# %% [markdown]
# <a href="https://colab.research.google.com/github/Fanira/Fani-Ramadhanty_PABCL2023/blob/main/Copy_of_Fani_Ramadhanty_PABCL2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Peringkat Universitas QS WORLD EDA + Analisis
# https://www.kaggle.com/code/natchimuthun/qs-world-university-rankings-eda-analysis/notebook
#
#
# Dataset ini berisikan informasi terkait penilaian universitas menurut Universitas QS WORLD EDA. Saya memilih dataset ini dikarenakan ingin mengetahui  Universitas apa saja yang masuk keperingkat 10 besar, juga ingin menegtahui Universitas terbaik di Indonesia masuk kedalam peringkat keberapa. Dari dataset ini juga kita bisa menegtahui berapa angka nilai yang diberikan kepada Universitas terbaik disetiap negara yang terpilih.

# %%
import pandas as pd
from pandas import ExcelFile

data1 = pd.read_csv('data1.csv')
data1.head(2)
# Out:
#    Year  Rank                     Name  Point       City          Country
# 0  2018     1       Harvard University   97.7  Cambridge    United States
# 1  2018     2  University of Cambridge   94.6  Cambridge   United Kingdom

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from pandas import ExcelFile

data1 = pd.read_csv('/content/drive/MyDrive/DataSet/data1.csv')

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
  for filename in filenames:
    print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path='/kaggle/input/qs-world-ranked-universities-20182022/data1.csv'
data1= pd.read_csv('data1.csv')
data1.head()
data1.tail()
# Out:
#       Year  Rank  ...         City         Country
# 5245  2022   346  ...  Tainan City          Taiwan
# 5246  2022   346  ...  Albuquerque   United States
# 5247  2022   348  ...        Depok       Indonesia
# 5248  2022   349  ...      Karachi        Pakistan
# 5249  2022   349  ...       Boston   United States
#
# [5 rows x 6 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     5250 non-null   int64
#  1   Rank     5250 non-null   int64
#  2   Name     5250 non-null   object
#  3   Point    5030 non-null   float64
#  4   City     5250 non-null   object
#  5   Country  5249 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 246.2+ KB

# %% [markdown]
# ## 1. Tampilkan 5 ranking teratas dan 5 rangking terbawah universitas?

# %%
display(data1.head())
print()
display(data1.tail())
# Out:
#    Year  Rank  ...       City          Country
# 0  2018     1  ...  Cambridge    United States
# 1  2018     2  ...  Cambridge   United Kingdom
# 2  2018     2  ...     Oxford   United Kingdom
# 3  2018     4  ...  Cambridge    United States
# 4  2018     5  ...  Baltimore    United States
#
# [5 rows x 6 columns]
#       Year  Rank  ...         City         Country
# 5245  2022   346  ...  Tainan City          Taiwan
# 5246  2022   346  ...  Albuquerque   United States
# 5247  2022   348  ...        Depok       Indonesia
# 5248  2022   349  ...      Karachi        Pakistan
# 5249  2022   349  ...       Boston   United States
#
# [5 rows x 6 columns]

# %% [markdown]
# ## 2. Tampilkan info data!

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     5250 non-null   int64
#  1   Rank     5250 non-null   int64
#  2   Name     5250 non-null   object
#  3   Point    5030 non-null   float64
#  4   City     5250 non-null   object
#  5   Country  5249 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 246.2+ KB

# %% [markdown]
# ## 3. Universitas apa saja yang masuk ke peringkat 10 besar?

# %%
data1[data1['Rank'] < 11]
# Out:
#       Year  Rank  ...           City          Country
# 0     2018     1  ...      Cambridge    United States
# 1     2018     2  ...      Cambridge   United Kingdom
# 2     2018     2  ...         Oxford   United Kingdom
# 3     2018     4  ...      Cambridge    United States
# 4     2018     5  ...      Baltimore    United States
# ...    ...   ...  ...            ...              ...
# 4905  2022     6  ...      Cambridge    United States
# 4906  2022     7  ...      Stockholm           Sweden
# 4907  2022     8  ...         London   United Kingdom
# 4908  2022     9  ...  San Francisco    United States
# 4909  2022    10  ...         London   United Kingdom
#
# [150 rows x 6 columns]

# %% [markdown]
# ## 4. Berapa banyaknya distribusi universitas per negara?

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=data1,x='Country')
plt.title('Number of Universities in QS University Rankings by Country')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# kesimpulan : dari sini kita mengetahui bahwa Indonesia termasuk kepada distribusi universitas paling rendah sekali

# %% [markdown]
# ## 5. Tampilkan Universitas Indonesia!

# %%
data1.iloc[5247:5248]
# Out:
#       Year  Rank                   Name  Point   City     Country
# 5247  2022   348  Universitas Indonesia   60.6  Depok   Indonesia

# %%
data1[5247:5248]
# Out:
#       Year  Rank                   Name  Point   City     Country
# 5247  2022   348  Universitas Indonesia   60.6  Depok   Indonesia

# %% [markdown]
# ## 6. Ada berapakah Universitas yang masuk menurut panilaian Univeritas Dunia ditahun 2018?

# %%
data1[data1['Year'] == 2018]
# Out:
#      Year  Rank  ...       City          Country
# 0    2018     1  ...  Cambridge    United States
# 1    2018     2  ...  Cambridge   United Kingdom
# 2    2018     2  ...     Oxford   United Kingdom
# 3    2018     4  ...  Cambridge    United States
# 4    2018     5  ...  Baltimore    United States
# ..    ...   ...  ...        ...              ...
# 345  2018   344  ...   Richmond    United States
# 346  2018   344  ...      Wuhan            China
# 347  2018   348  ...      Delft      Netherlands
# 348  2018   348  ...   Pretoria     South Africa
# 349  2018   350  ...  Milwaukee    United States
#
# [350 rows x 6 columns]

# %% [markdown]
# kesimpulan: dari sini kita mengetahui bahwa jumlah Universitas yang masuk di tahun 2018 sekitar 348
